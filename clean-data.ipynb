# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20, 10)

# %%
df=pd.read_csv("apr20_price_33_col.csv",index_col=0)

df.head()
# Out:
#            obj_regio1  obj_heatingType     obj_cId obj_newlyConst  \
# 0             Sachsen        heat_pump    544685.0              y
# 1              Berlin  central_heating   5240003.0              n
# 2   Baden_Württemberg    stove_heating    954015.0              n
# 3  Schleswig_Holstein              NaN    134629.0              n
# 4       Niedersachsen              NaN  18406763.0              n
#
#    obj_pricetrend  obj_yearConstructed  obj_pricetrendbuy obj_firingTypes  \
# 0            9.12               2021.0               9.12  no_information
# 1           11.35               1934.0              11.35             gas
# 2            5.59               1920.0               5.59            wood
# 3            9.62               1972.0               9.62             gas
# 4           11.40                  NaN              11.40  no_information
#
#   obj_ExclusiveExpose             geo_bln  ...  \
# 0                True             Sachsen  ...
# ...

# %%
drop_cols = [
    "obj_cId",
    "obj_pricetrend",
    "obj_pricetrendbuy",
    "obj_ExclusiveExpose",
    "geo_bln",
    "obj_streetPlain",
    "obj_zipCode",
    "geo_land",
    "obj_immotype",
    "obj_objectnumber",
    "obj_regio2",
    "ga_cd_via"
    
    
]

df = df.drop(columns=drop_cols)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 18
#      14
#      15
#      16 ]
#      17
# ---> 18 df = df.drop(columns=drop_cols)
#
# File c:\Users\hania\Desktop\die Weiterbildng\hoky_immobilien\.venv\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File c:\Users\hania\Desktop\die Weiterbildng\hoky_immobilien\.venv\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
df.head()
# Out:
#            obj_regio1  obj_heatingType obj_newlyConst  obj_yearConstructed  \
# 0             Sachsen        heat_pump              y               2021.0
# 1              Berlin  central_heating              n               1934.0
# 2   Baden_Württemberg    stove_heating              n               1920.0
# 3  Schleswig_Holstein              NaN              n               1972.0
# 4       Niedersachsen              NaN              n                  NaN
#
#   obj_firingTypes obj_cellar obj_houseNumber  obj_livingSpace  \
# 0  no_information          n  no_information           152.00
# 1             gas          y               0            65.00
# 2            wood          y  no_information           159.00
# 3             gas          y  no_information           104.78
# 4  no_information          n  no_information           140.00
#
#               geo_krs   obj_condition  ...  geo_plz  obj_noRooms  \
# 0       Leipzig_Kreis  first_time_use  ...   4571.0          4.0
# ...

# %%
df.shape
# Out:
# (46262, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46262 entries, 0 to 46261
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   obj_regio1                           46262 non-null  str
#  1   obj_heatingType                      39004 non-null  str
#  2   obj_newlyConst                       46262 non-null  str
#  3   obj_yearConstructed                  40276 non-null  float64
#  4   obj_firingTypes                      43063 non-null  str
#  5   obj_cellar                           46262 non-null  str
#  6   obj_houseNumber                      46262 non-null  str
#  7   obj_livingSpace                      46262 non-null  float64
#  8   geo_krs                              46262 non-null  str
#  9   obj_condition                        46262 non-null  str
#  10  obj_street                           46262 non-null  str
# ...

# %%
df.describe()
# Out:
#        obj_yearConstructed  obj_livingSpace       geo_plz   obj_noRooms  \
# count         40276.000000     46262.000000  46262.000000  46262.000000
# mean           1963.727406       211.710340  47663.892223      7.088669
# std              59.398147       329.564259  26612.305104      6.248201
# min            1058.000000         0.000000   1057.000000      1.000000
# 25%            1936.000000       126.000000  25560.000000      4.500000
# 50%            1973.000000       160.040000  47546.000000      6.000000
# 75%            2002.000000       233.000000  67823.000000      8.000000
# max            5410.000000     38500.000000  99998.000000    400.000000
#
#        obj_livingSpaceRange  obj_purchasePrice
# count          46262.000000       4.626200e+04
# mean               4.699062       5.408054e+05
# std                2.320387       1.213126e+06
# min                1.000000       0.000000e+00
# 25%                3.000000       2.400000e+05
# ...

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop(columns=["Unnamed: 0"], inplace=True)
#
# File c:\Users\hania\Desktop\die Weiterbildng\hoky_immobilien\.venv\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File c:\Users\hania\Desktop\die Weiterbildng\hoky_immobilien\.venv\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
df.head()
# Out:
#            obj_regio1  obj_heatingType obj_newlyConst  obj_yearConstructed  \
# 0             Sachsen        heat_pump              y               2021.0
# 1              Berlin  central_heating              n               1934.0
# 2   Baden_Württemberg    stove_heating              n               1920.0
# 3  Schleswig_Holstein              NaN              n               1972.0
# 4       Niedersachsen              NaN              n                  NaN
#
#   obj_firingTypes obj_cellar obj_houseNumber  obj_livingSpace  \
# 0  no_information          n  no_information           152.00
# 1             gas          y               0            65.00
# 2            wood          y  no_information           159.00
# 3             gas          y  no_information           104.78
# 4  no_information          n  no_information           140.00
#
#               geo_krs   obj_condition  ...  geo_plz  obj_noRooms  \
# 0       Leipzig_Kreis  first_time_use  ...   4571.0          4.0
# ...

# %%
df.columns
# Out:
# Index(['obj_regio1', 'obj_heatingType', 'obj_newlyConst',
#        'obj_yearConstructed', 'obj_firingTypes', 'obj_cellar',
#        'obj_houseNumber', 'obj_livingSpace', 'geo_krs', 'obj_condition',
#        'obj_street', 'geo_plz', 'obj_noRooms',
#        'obj_telekomInternetProductAvailable', 'obj_barrierFree', 'obj_regio3',
#        'obj_livingSpaceRange', 'obj_telekomTvOffer', 'obj_telekomUploadSpeed',
#        'obj_telekomDownloadSpeed', 'obj_purchasePrice'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# obj_regio1                                0
# obj_heatingType                        7258
# obj_newlyConst                            0
# obj_yearConstructed                    5986
# obj_firingTypes                        3199
# obj_cellar                                0
# obj_houseNumber                           0
# obj_livingSpace                           0
# geo_krs                                   0
# obj_condition                             0
# obj_street                                0
# geo_plz                                   0
# obj_noRooms                               0
# obj_telekomInternetProductAvailable    3160
# obj_barrierFree                           0
# obj_regio3                                0
# obj_livingSpaceRange                      0
# obj_telekomTvOffer                     7936
# obj_telekomUploadSpeed                 8739
# obj_telekomDownloadSpeed               8738
# obj_purchasePrice                         0
# dtype: int64

# %%
df.head()
# Out:
#            obj_regio1  obj_heatingType obj_newlyConst  obj_yearConstructed  \
# 0             Sachsen        heat_pump              y               2021.0
# 1              Berlin  central_heating              n               1934.0
# 2   Baden_Württemberg    stove_heating              n               1920.0
# 3  Schleswig_Holstein              NaN              n               1972.0
# 4       Niedersachsen              NaN              n                  NaN
#
#   obj_firingTypes obj_cellar obj_houseNumber  obj_livingSpace  \
# 0  no_information          n  no_information           152.00
# 1             gas          y               0            65.00
# 2            wood          y  no_information           159.00
# 3             gas          y  no_information           104.78
# 4  no_information          n  no_information           140.00
#
#               geo_krs   obj_condition  ...  geo_plz  obj_noRooms  \
# 0       Leipzig_Kreis  first_time_use  ...   4571.0          4.0
# ...

# %%
df.groupby("obj_regio1")["obj_regio1"].agg("count")
# Out:
# obj_regio1
# Baden_Württemberg         5421
# Bayern                    5512
# Berlin                     882
# Brandenburg               2164
# Bremen                     329
# Hamburg                    509
# Hessen                    3760
# Mecklenburg_Vorpommern    1667
# Niedersachsen             5592
# Nordrhein_Westfalen       7733
# Rheinland_Pfalz           3975
# Saarland                   905
# Sachsen                   2481
# Sachsen_Anhalt            1598
# Schleswig_Holstein        2910
# Thüringen                  824
# Name: obj_regio1, dtype: int64

# %%
df = df[df['obj_regio1'] == 'Niedersachsen'].copy()
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#       obj_regio1  obj_heatingType obj_newlyConst  obj_yearConstructed  \
# 0  Niedersachsen              NaN              n                  NaN
# 1  Niedersachsen  central_heating              n                  NaN
# 2  Niedersachsen  central_heating              n               2013.0
# 3  Niedersachsen  central_heating              n               1909.0
# 4  Niedersachsen              NaN              n                  NaN
#
#   obj_firingTypes obj_cellar obj_houseNumber  obj_livingSpace  \
# 0  no_information          n  no_information            140.0
# 1             gas          n  no_information            100.0
# 2             gas          n  no_information            170.0
# 3             oil          n  no_information            170.0
# 4  no_information          n  no_information            140.0
#
#            geo_krs   obj_condition  ...  geo_plz  obj_noRooms  \
# 0    Emsland_Kreis  no_information  ...  49774.0          5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5592 entries, 0 to 5591
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   obj_regio1                           5592 non-null   str
#  1   obj_heatingType                      4673 non-null   str
#  2   obj_newlyConst                       5592 non-null   str
#  3   obj_yearConstructed                  5055 non-null   float64
#  4   obj_firingTypes                      5335 non-null   str
#  5   obj_cellar                           5592 non-null   str
#  6   obj_houseNumber                      5592 non-null   str
#  7   obj_livingSpace                      5592 non-null   float64
#  8   geo_krs                              5592 non-null   str
#  9   obj_condition                        5592 non-null   str
#  10  obj_street                           5592 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# obj_regio1                                0
# obj_heatingType                         919
# obj_newlyConst                            0
# obj_yearConstructed                     537
# obj_firingTypes                         257
# obj_cellar                                0
# obj_houseNumber                           0
# obj_livingSpace                           0
# geo_krs                                   0
# obj_condition                             0
# obj_street                                0
# geo_plz                                   0
# obj_noRooms                               0
# obj_telekomInternetProductAvailable     367
# obj_barrierFree                           0
# obj_regio3                                0
# obj_livingSpaceRange                      0
# obj_telekomTvOffer                      959
# obj_telekomUploadSpeed                 1101
# obj_telekomDownloadSpeed               1101
# obj_purchasePrice                         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# obj_regio1                                0
# obj_heatingType                         919
# obj_newlyConst                            0
# obj_yearConstructed                     537
# obj_firingTypes                         257
# obj_cellar                                0
# obj_houseNumber                           0
# obj_livingSpace                           0
# geo_krs                                   0
# obj_condition                             0
# obj_street                                0
# geo_plz                                   0
# obj_noRooms                               0
# obj_telekomInternetProductAvailable     367
# obj_barrierFree                           0
# obj_regio3                                0
# obj_livingSpaceRange                      0
# obj_telekomTvOffer                      959
# obj_telekomUploadSpeed                 1101
# obj_telekomDownloadSpeed               1101
# obj_purchasePrice                         0
# dtype: int64

# %%
df['obj_heatingType'] = df['obj_heatingType'].fillna('null', inplace=True)
df['obj_firingTypes'] = df['obj_firingTypes'].fillna('null', inplace=True)
df['obj_telekomUploadSpeed'] = df['obj_telekomUploadSpeed'].fillna('null')
df['obj_telekomDownloadSpeed'] = df['obj_telekomDownloadSpeed'].fillna('null')
# Out:
# C:\Users\hania\AppData\Local\Temp\ipykernel_16936\221282089.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['obj_heatingType'] = df['obj_heatingType'].fillna('null', inplace=True)
# ...

# %%
df.isnull().sum()
# Out:
# obj_regio1                               0
# obj_heatingType                          0
# obj_newlyConst                           0
# obj_yearConstructed                    537
# obj_firingTypes                          0
# obj_cellar                               0
# obj_houseNumber                          0
# obj_livingSpace                          0
# geo_krs                                  0
# obj_condition                            0
# obj_street                               0
# geo_plz                                  0
# obj_noRooms                              0
# obj_telekomInternetProductAvailable    367
# obj_barrierFree                          0
# obj_regio3                               0
# obj_livingSpaceRange                     0
# obj_telekomTvOffer                     959
# obj_telekomUploadSpeed                   0
# obj_telekomDownloadSpeed                 0
# obj_purchasePrice                        0
# dtype: int64

# %%
df.drop(columns=["obj_telekomInternetProductAvailable"], inplace=True)

# %%
df.isnull().sum()
# Out:
# obj_regio1                    0
# obj_heatingType               0
# obj_newlyConst                0
# obj_yearConstructed         537
# obj_firingTypes               0
# obj_cellar                    0
# obj_houseNumber               0
# obj_livingSpace               0
# geo_krs                       0
# obj_condition                 0
# obj_street                    0
# geo_plz                       0
# obj_noRooms                   0
# obj_barrierFree               0
# obj_regio3                    0
# obj_livingSpaceRange          0
# obj_telekomTvOffer          959
# obj_telekomUploadSpeed        0
# obj_telekomDownloadSpeed      0
# obj_purchasePrice             0
# dtype: int64

# %%
df.to_csv("price_clean.csv", index=False)

# %%
df['obj_telekomTvOffer'] = df['obj_telekomTvOffer'].fillna('None')

# %%
df.isnull().sum()
# Out:
# obj_regio1                    0
# obj_heatingType               0
# obj_newlyConst                0
# obj_yearConstructed         537
# obj_firingTypes               0
# obj_cellar                    0
# obj_houseNumber               0
# obj_livingSpace               0
# geo_krs                       0
# obj_condition                 0
# obj_street                    0
# geo_plz                       0
# obj_noRooms                   0
# obj_barrierFree               0
# obj_regio3                    0
# obj_livingSpaceRange          0
# obj_telekomTvOffer            0
# obj_telekomUploadSpeed        0
# obj_telekomDownloadSpeed      0
# obj_purchasePrice             0
# dtype: int64

# %%
df['obj_yearConstructed'] = df['obj_yearConstructed'].fillna(df['obj_yearConstructed'].median())

# %%
df.isnull().sum()
# Out:
# obj_regio1                  0
# obj_heatingType             0
# obj_newlyConst              0
# obj_yearConstructed         0
# obj_firingTypes             0
# obj_cellar                  0
# obj_houseNumber             0
# obj_livingSpace             0
# geo_krs                     0
# obj_condition               0
# obj_street                  0
# geo_plz                     0
# obj_noRooms                 0
# obj_barrierFree             0
# obj_regio3                  0
# obj_livingSpaceRange        0
# obj_telekomTvOffer          0
# obj_telekomUploadSpeed      0
# obj_telekomDownloadSpeed    0
# obj_purchasePrice           0
# dtype: int64
